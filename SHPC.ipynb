# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SHPC.csv')

# %%
df.head()
# Out:
#   published_date   open   high    low  close  per_change  traded_quantity  \
# 0     2014-03-24  540.0  566.0  538.0  560.0         NaN          10249.0
# 1     2014-03-25  560.0  580.0  547.0  570.0        1.79          21974.0
# 2     2014-03-26  570.0  589.0  560.0  584.0        2.46          22124.0
# 3     2014-03-27  584.0  605.0  580.0  604.0        3.42          39017.0
# 4     2014-03-31  604.0  632.0  600.0  632.0        4.64          19441.0
#
#    traded_amount  status
# 0      5655906.0       0
# 1     12463350.0       0
# 2     12720203.0       0
# 3     23315656.0       0
# 4     12044508.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2853 entries, 0 to 2852
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2853 non-null   object
#  1   open             2853 non-null   float64
#  2   high             2853 non-null   float64
#  3   low              2853 non-null   float64
#  4   close            2853 non-null   float64
#  5   per_change       2852 non-null   float64
#  6   traded_quantity  2853 non-null   float64
#  7   traded_amount    2853 non-null   float64
#  8   status           2853 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 200.7+ KB

# %%
df = df.copy()

# %%
df["published_date"] = pd.to_datetime(df["published_date"])

# %%
df.head()
# Out:
#   published_date   open   high    low  close  per_change  traded_quantity  \
# 0     2014-03-24  540.0  566.0  538.0  560.0         NaN          10249.0
# 1     2014-03-25  560.0  580.0  547.0  570.0        1.79          21974.0
# 2     2014-03-26  570.0  589.0  560.0  584.0        2.46          22124.0
# 3     2014-03-27  584.0  605.0  580.0  604.0        3.42          39017.0
# 4     2014-03-31  604.0  632.0  600.0  632.0        4.64          19441.0
#
#    traded_amount  status
# 0      5655906.0       0
# 1     12463350.0       0
# 2     12720203.0       0
# 3     23315656.0       0
# 4     12044508.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2853 entries, 0 to 2852
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2853 non-null   datetime64[ns]
#  1   open             2853 non-null   float64
#  2   high             2853 non-null   float64
#  3   low              2853 non-null   float64
#  4   close            2853 non-null   float64
#  5   per_change       2852 non-null   float64
#  6   traded_quantity  2853 non-null   float64
#  7   traded_amount    2853 non-null   float64
#  8   status           2853 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 200.7 KB

# %%
plt.bar(df['published_date'], df['traded_quantity'])
plt.xlabel('published_date')
plt.ylabel('traded_quantity')
plt.title('Date and Traded Quantity')
plt.show()

# %%
df.dtypes
# Out:
# published_date     datetime64[ns]
# open                      float64
# high                      float64
# low                       float64
# close                     float64
# per_change                float64
# traded_quantity           float64
# traded_amount             float64
# status                      int64
# dtype: object

# %%
df.loc[df['traded_quantity'].idxmax()]
# Out:
# published_date     2025-05-06 00:00:00
# open                             584.0
# high                             617.0
# low                              584.0
# close                            614.2
# per_change                        5.24
# traded_quantity              1532482.0
# traded_amount              928962766.8
# status                               1
# Name: 2547, dtype: object

# %%
print(df.nlargest(10, 'traded_quantity')[['published_date','traded_quantity']])
# Out:
#      published_date  traded_quantity
# 2547     2025-05-06        1532482.0
# 2543     2025-04-29        1450691.0
# 2573     2025-06-16        1435902.0
# 2572     2025-06-15        1343025.0
# 2386     2024-08-15        1272947.0
# 2571     2025-06-12        1180505.0
# 2602     2025-07-27        1167756.0
# 2574     2025-06-17        1161879.0
# 2575     2025-06-18        1091837.0
# 2549     2025-05-08        1043743.0

# %%
df.loc[df['low'].idxmin()]
# Out:
# published_date     2019-12-23 00:00:00
# open                             165.0
# high                             175.0
# low                              165.0
# close                            175.0
# per_change                       -4.37
# traded_quantity                11538.0
# traded_amount                1965043.0
# status                              -1
# Name: 1337, dtype: object

# %%
df.isnull().sum()
# Out:
# published_date     0
# open               0
# high               0
# low                0
# close              0
# per_change         1
# traded_quantity    0
# traded_amount      0
# status             0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#   published_date   open   high    low  close  per_change  traded_quantity  \
# 0     2014-03-24  540.0  566.0  538.0  560.0         NaN          10249.0
#
#    traded_amount  status
# 0      5655906.0       0

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df[df['published_date'].duplicated(keep=False)]
# Out:
#      published_date   open   high    low  close  per_change  traded_quantity  \
# 32       2014-05-15  640.0  650.0  612.0  645.0        0.78           2409.0
# 33       2014-05-15  640.0  650.0  612.0  645.0        0.00           2409.0
# 55       2014-06-17  691.0  699.0  681.0  699.0        1.16           5555.0
# 56       2014-06-17  691.0  699.0  681.0  699.0        0.00           5555.0
# 176      2014-12-28  699.0  712.0  705.0  705.0        0.86           3606.0
# 177      2014-12-28  699.0  712.0  705.0  705.0        0.00           3606.0
# 210      2015-02-16  800.0  801.0  792.0  799.0       -0.12           2159.0
# 211      2015-02-16  800.0  801.0  792.0  799.0        0.00           2159.0
# 263      2015-06-08  670.0  737.0  683.0  716.0        6.87           1805.0
# 264      2015-06-08  670.0  737.0  683.0  716.0        0.00           1805.0
# 265      2015-06-08  670.0  737.0  683.0  716.0        0.00           1805.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2853 entries, 0 to 2852
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2853 non-null   datetime64[ns]
#  1   open             2853 non-null   float64
#  2   high             2853 non-null   float64
#  3   low              2853 non-null   float64
#  4   close            2853 non-null   float64
#  5   per_change       2852 non-null   float64
#  6   traded_quantity  2853 non-null   float64
#  7   traded_amount    2853 non-null   float64
#  8   status           2853 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 200.7 KB

# %%
df['close'].mean()
# Out:
# np.float64(500.57909218366626)

# %%
df['close'].min()
# Out:
# 166.0

# %%
df['close'].max()
# Out:
# 1239.0

# %%
df.loc[df['close'].idxmax(), ['published_date','close','per_change','traded_amount']]
# Out:
# published_date    2017-05-09 00:00:00
# close                          1239.0
# per_change                       8.21
# traded_amount              46923232.0
# Name: 715, dtype: object

# %%
df.nlargest(10, 'close') [['close','published_date','traded_amount']]
# Out:
#       close published_date  traded_amount
# 715  1239.0     2017-05-09     46923232.0
# 720  1204.0     2017-05-18     16666886.0
# 724  1200.0     2017-05-24      9777196.0
# 716  1195.0     2017-05-11     49815672.0
# 719  1190.0     2017-05-17      6989962.0
# 721  1190.0     2017-05-21      9030034.0
# 717  1189.0     2017-05-15     18609962.0
# 722  1187.0     2017-05-22      5934976.0
# 718  1185.0     2017-05-16     11977939.0
# 727  1180.0     2017-05-31     13333121.0

# %%
#largest one day gain
df.nlargest(10, 'per_change') [['published_date','per_change','close']]
# Out:
#      published_date  per_change   close
# 68       2014-07-06       10.00   792.0
# 512      2016-06-22       10.00  1122.0
# 663      2017-02-15       10.00   825.0
# 1627     2021-06-02       10.00   506.0
# 1691     2021-09-06       10.00   565.4
# 1181     2019-04-30        9.96   276.0
# 1881     2022-06-26        9.96   302.4
# 2377     2024-08-01        9.96   497.0
# 1623     2021-05-27        9.86   479.0
# 1352     2020-01-13        9.78   202.0

# %%
df.nsmallest(10, 'per_change') [
    ['published_date','per_change','close']
    ]
# Out:
#      published_date  per_change  close
# 764      2017-07-25      -43.35  626.0
# 256      2015-05-28       -9.96  633.0
# 108      2014-09-07       -8.96  610.0
# 1690     2021-09-05       -8.05  514.0
# 1387     2020-03-02       -7.76  226.0
# 581      2016-10-05       -7.75  917.0
# 1197     2019-05-23       -7.36  277.0
# 1940     2022-09-06       -7.32  291.0
# 1709     2021-10-03       -7.26  447.0
# 651      2017-01-30       -7.15  701.0

# %%
plt.plot(df['published_date'], df['traded_amount'])
plt.xlabel('published_date')
plt.ylabel('Traded_Amount')
plt.title('Date and Amount Comparision')
plt.show()

# %%
plt.plot(df['published_date'], df['close'])

plt.title('Date and Close Date Analysis')
plt.xlabel('published_date')
plt.ylabel('Close Amount')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2853 entries, 0 to 2852
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   published_date   2853 non-null   datetime64[ns]
#  1   open             2853 non-null   float64
#  2   high             2853 non-null   float64
#  3   low              2853 non-null   float64
#  4   close            2853 non-null   float64
#  5   per_change       2852 non-null   float64
#  6   traded_quantity  2853 non-null   float64
#  7   traded_amount    2853 non-null   float64
#  8   status           2853 non-null   int64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 200.7 KB

# %%
df['Daily_Return'] = df['close'].pct_change()

# %%
df['Daily_Return_Percentage'] = df['Daily_Return'] * 100

# %%
df['Daily_Return_Percentage'].describe()
# Out:
# count    2852.000000
# mean        0.028887
# std         2.501003
# min       -43.348416
# 25%        -1.212121
# 50%        -0.085801
# 75%         1.040313
# max        10.000000
# Name: Daily_Return_Percentage, dtype: float64

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df['Daily_Return_Pct'].dropna(),
    bins=50
)

plt.title('Distribution of Daily SHPC Returns')
plt.xlabel('Daily Return Percentage')
plt.ylabel('Frequency')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Daily_Return_Pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 4
#       1 plt.figure(figsize=(10,6))
# ...
