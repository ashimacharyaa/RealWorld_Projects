# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
import pandas as pd

df = pd.DataFrame({
    'Age': [20, 25, 30, 35],
    'Salary': [30000, 40000, 50000, 60000],
    'City': ['Kathmandu', 'Pokhara', 'Kathmandu', 'Lalitpur'],
    'Gender': ['Male', 'Female', 'Female', 'Male']
})

# %%
numeric_cols = ["Age","Salary"]
categorical_cols =["City","Gender"]

# %%
transformer = ColumnTransformer(
    transformers = [
        ('num',StandardScaler(), numeric_cols),
        ('col',OneHotEncoder(), categorical_cols)
    ]
)

# %%
X_transformed = transformer.fit_transform(df)

# %%
X_transformed = pd.DataFrame(
    X_transformed,
    columns=transformer.get_feature_names_out()
)

# %%
print(X_transformed)
# Out:
#    num__Age  num__Salary  col__City_Kathmandu  col__City_Lalitpur  \
# 0 -1.341641    -1.341641                  1.0                 0.0
# 1 -0.447214    -0.447214                  0.0                 0.0
# 2  0.447214     0.447214                  1.0                 0.0
# 3  1.341641     1.341641                  0.0                 1.0
#
#    col__City_Pokhara  col__Gender_Female  col__Gender_Male
# 0                0.0                 0.0               1.0
# 1                1.0                 1.0               0.0
# 2                0.0                 1.0               0.0
# 3                0.0                 0.0               1.0
