# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.DataFrame({
    'Age':[22,25,28,32,35,40],
    'Salary': [30000, 35000, 40000, 50000, 60000, 75000],
    'Experience': [1, 2, 4, 6, 8, 12]
})
print(df)
# Out:
#    Age  Salary  Experience
# 0   22   30000           1
# 1   25   35000           2
# 2   28   40000           4
# 3   32   50000           6
# 4   35   60000           8
# 5   40   75000          12

# %%
x = df[['Age','Salary','Experience']]

# %%
scaler =  StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
print(x_scaled)
# Out:
# [[-1.37205325 -1.18616051 -1.20627104]
#  [-0.87811408 -0.86266219 -0.93821081]
#  [-0.38417491 -0.53916387 -0.40209035]
#  [ 0.27441065  0.10783277  0.13403012]
#  [ 0.76834982  0.75482941  0.67015058]
#  [ 1.59158177  1.72532437  1.7423915 ]]

# %%
pca = PCA(n_components=2)

x_pca = pca.fit_transform(x_scaled)

print(x_pca)
# Out:
# [[-2.17331341 -0.14576849]
#  [-1.54674088  0.00909669]
#  [-0.76527009  0.08333384]
#  [ 0.29797416  0.12690384]
#  [ 1.266268    0.03739366]
#  [ 2.92108222 -0.11095955]]

# %%
df_pca = pd.DataFrame(
    x_pca,
    columns=['PC1', 'PC2']
)

print(df_pca)
# Out:
#         PC1       PC2
# 0 -2.173313 -0.145768
# 1 -1.546741  0.009097
# 2 -0.765270  0.083334
# 3  0.297974  0.126904
# 4  1.266268  0.037394
# 5  2.921082 -0.110960

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(
    x_pca[:,0],
    x_pca[:,1],
)
plt.show()
