# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame({
    'Experience': [1, 2, 3, 4, 5, 6, 7, 8],
    'Salary': [30000, 35000, 42000, 48000, 55000, 62000, 70000, 78000]
})

print(df)
# Out:
#    Experience  Salary
# 0           1   30000
# 1           2   35000
# 2           3   42000
# 3           4   48000
# 4           5   55000
# 5           6   62000
# 6           7   70000
# 7           8   78000

# %%
x = df[['Experience']]
y = df['Salary']

# %%
#training the models
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size = 0.2,
    random_state = 42
)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [35460. 63020.]

# %%
#model parameters
print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 6889.999999999998
# Intercept: 21680.000000000007

# %%
#predictions on new unseen data
new_data = pd.DataFrame({
    'Experience': [9,10,11]
})

predictions = model.predict(new_data)
print("predictions:")
print(predictions)
# Out:
# predictions:
# [83690. 90580. 97470.]

# %%
#visualization
import seaborn as sns
plt.scatter(x,y)
plt.plot(x,model.predict(x))
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Salary Compare With Experience")
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 #visualization
# ----> 2 plt.scatter(x,y)
#       3 plt.plot(x,model.predict(x))
#       4 plt.xlabel("Experience")
#
# NameError: name 'plt' is not defined
